# %% [markdown]
# <img src="https://m.media-amazon.com/images/I/B112teWM7eL.png" style="height:550px" />

# %% [markdown]
# # Classifying Genres Using Spotify's Top Songs
#
#
# ***
# Author: Andre Layton
# ***

# %% [markdown]
# # Overview
#
# -Music is always evolving but despite that subscribers want their playlists/recommendations to be flawless in their search for new music.
# -Pop is one of the biggest genres in the world, for decades.
#
# # Business Problem
# -Create a model that will classify and identify pop songs.

# %% [markdown]
# ***
# ![Header](images/header_picture3.jpg)

# %% [markdown]
# # Data Understanding

# %%
#Import libraries
import pandas as pd
import numpy as np
import math
from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import AutoMinorLocator
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.metrics import precision_score, accuracy_score, f1_score, confusion_matrix, classification_report, roc_curve, auc, ConfusionMatrixDisplay
from sklearn.tree import DecisionTreeClassifier

# %%
spotify_df = pd.read_csv('data/Best Songs on Spotify from 2000-2023.csv', delimiter=';')
spotify_df.head(15)
# Out:
#                                      title          artist  \
# 0                                  Flowers     Miley Cyrus
# 1                        Cupid - Twin Ver.     FIFTY FIFTY
# 2                                     BESO         ROSALÍA
# 3                       Boy's a liar Pt. 2  PinkPantheress
# 4   Creepin' (with The Weeknd & 21 Savage)    Metro Boomin
# 5                                 Daylight   David Kushner
# 6                                      TQG         KAROL G
# 7            Calm Down (with Selena Gomez)            Rema
# 8                                Anti-Hero    Taylor Swift
# 9                             Here With Me            d4vd
# 10                         I'm Good (Blue)    David Guetta
# 11                               Kill Bill             SZA
# 12                     Die For You - Remix      The Weeknd
# 13                         I Ain't Worried     OneRepublic
# 14    Quevedo: Bzrp Music Sessions Vol. 52        Bizarrap
#
# ...

# %%
spotify_df['top genre'].value_counts()
# Out:
# dance pop            460
# pop                  250
# atl hip hop           95
# alternative metal     55
# edm                   54
#                     ...
# romanian pop           1
# bass house             1
# cloud rap              1
# classic schlager       1
# sad lo-fi              1
# Name: top genre, Length: 266, dtype: int64

# %%
spotify_df.describe()
# Out:
#               year          bpm       energy  danceability            dB  \
# count  2385.000000  2385.000000  2385.000000    2385.000000  2385.000000
# mean   2011.116981   119.783648    69.792453      67.034801    -5.771488
# std       6.748364    27.273075    16.164609      13.719049     2.072153
# min    1985.000000    60.000000     6.000000      18.000000   -18.000000
# 25%    2005.000000    98.000000    59.000000      59.000000    -7.000000
# 50%    2011.000000   120.000000    71.000000      68.000000    -5.000000
# 75%    2017.000000   134.000000    82.000000      77.000000    -4.000000
# max    2023.000000   211.000000   100.000000      98.000000     0.000000
#
#           liveness      valence     duration  acousticness  speechiness   \
# count  2385.000000  2385.000000  2385.000000   2385.000000   2385.000000
# mean     17.787002    54.233962   225.946751     15.612998     10.112369
# std      13.629287    22.458084    43.226704     20.277746      9.520815
# ...

# %%
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2385 entries, 0 to 2384
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          2385 non-null   object
#  1   artist         2385 non-null   object
#  2   top genre      2385 non-null   object
#  3   year           2385 non-null   int64
#  4   bpm            2385 non-null   int64
#  5   energy         2385 non-null   int64
#  6   danceability   2385 non-null   int64
#  7   dB             2385 non-null   int64
#  8   liveness       2385 non-null   int64
#  9   valence        2385 non-null   int64
#  10  duration       2385 non-null   int64
#  11  acousticness   2385 non-null   int64
#  12  speechiness    2385 non-null   int64
#  13  popularity     2385 non-null   int64
# dtypes: int64(11), object(3)
# memory usage: 261.0+ KB

# %%
copy_df = spotify_df.copy()

# %%
def contains_pop(genre):
    word = "pop"
    if word in genre:
        return word
    else:
        return genre

copy_df['top genre'] = copy_df['top genre'].map(lambda x: contains_pop(x))
copy_df['top genre'].value_counts()
# Out:
# pop                        1061
# atl hip hop                  95
# alternative metal            55
# edm                          54
# contemporary r&b             43
#                            ...
# hardcore hip hop              1
# cloud rap                     1
# classic schlager              1
# irish singer-songwriter       1
# sad lo-fi                     1
# Name: top genre, Length: 205, dtype: int64

# %%
copy_df.head(15)
# Out:
#                                      title          artist  \
# 0                                  Flowers     Miley Cyrus
# 1                        Cupid - Twin Ver.     FIFTY FIFTY
# 2                                     BESO         ROSALÍA
# 3                       Boy's a liar Pt. 2  PinkPantheress
# 4   Creepin' (with The Weeknd & 21 Savage)    Metro Boomin
# 5                                 Daylight   David Kushner
# 6                                      TQG         KAROL G
# 7            Calm Down (with Selena Gomez)            Rema
# 8                                Anti-Hero    Taylor Swift
# 9                             Here With Me            d4vd
# 10                         I'm Good (Blue)    David Guetta
# 11                               Kill Bill             SZA
# 12                     Die For You - Remix      The Weeknd
# 13                         I Ain't Worried     OneRepublic
# 14    Quevedo: Bzrp Music Sessions Vol. 52        Bizarrap
#
# ...

# %%
# One hot encode the genres field between pop & not pop to create target column
# Look at correlation
# Build baseline model

# %%
copy_df.corr()
# Out:
#                    year       bpm    energy  danceability         dB  \
# year           1.000000  0.037433 -0.213572       0.032387 -0.078104
# bpm            0.037433  1.000000  0.128883      -0.175970  0.071543
# energy        -0.213572  0.128883  1.000000      -0.066279  0.678069
# danceability   0.032387 -0.175970 -0.066279       1.000000  0.009636
# dB            -0.078104  0.071543  0.678069       0.009636  1.000000
# liveness      -0.029241  0.011156  0.157227      -0.097046  0.089844
# valence       -0.233264 -0.022143  0.365791       0.379953  0.269899
# duration      -0.330849 -0.044491 -0.048563      -0.103807 -0.056888
# acousticness   0.159780 -0.098704 -0.523750      -0.098084 -0.383500
# speechiness   -0.023466  0.066764 -0.007322       0.149590 -0.053500
# popularity     0.205909 -0.019961 -0.120484      -0.019491 -0.004715
#
#                liveness   valence  duration  acousticness  speechiness   \
# ...

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.heatmap(copy_df.corr(), annot=True);
